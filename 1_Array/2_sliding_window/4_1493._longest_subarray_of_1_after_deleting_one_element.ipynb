# %%
MEDIUM

# %%
Given a binary array nums, you should delete one element from it.

Return the size of the longest non-empty subarray containing only 1's in the resulting array. Return 0 if there is no such subarray.



Example 1:

Input: nums = [1,1,0,1]
Output: 3
Explanation: After deleting the number in position 2, [1,1,1] contains 3 numbers with value of 1's.
Example 2:

Input: nums = [0,1,1,1,0,1,1,0,1]
Output: 5
Explanation: After deleting the number in position 4, [0,1,1,1,1,1,0,1] longest subarray with value of 1's is [1,1,1,1,1].
Example 3:

Input: nums = [1,1,1]
Output: 2
Explanation: You must delete one element.

# %%
class Solution:
    def longestSubarray(self, nums) -> int:
        start = end = zero_count = maxi = i = 0
        while i < len(nums):
            if nums[i] == 1:
                end = i
                i += 1
            else:
                if zero_count < 1:
                    zero_count = 1
                    end = i
                    i += 1

                else:
                    if nums[start] == 0:
                        zero_count = 0
                    start += 1
            maxi = max(maxi, end - start)
        return maxi

# %%
nums = [0,1,1,1,0,1,1,0,1]
Solution().longestSubarray(nums)
# Out:
# 5

# %%
class Solution:
    def longestSubarray(self, num) -> int:
        k = 1
        start = 0
        allowed_zero = k
        maxi = 0

        for end in range(len(num)):
            # increase the window by default
            if num[end] == 0:
                allowed_zero -= 1
            
            # strink the windown until the condition is met.
            while allowed_zero < 0:
                if num[start] == 0:
                   allowed_zero += 1
                start += 1

            # NOTE: same as the previous sum, you just consider k is always 1.
            # we should not consider the deleted element. so return only end - start not end-start+1.
            maxi = max(maxi, end - start)
        return  maxi

# %%
nums = [0,1,1,1,0,1,1,0,1]
Solution().longestSubarray(nums)
# Out:
# 5

# %%
Solution().longestSubarray(num = [1,1,0,1])
# Out:
# 3

# %%
Solution().longestSubarray(num = [1,1,1])
# Out:
# 2
