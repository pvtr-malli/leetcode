# %% [markdown]
# Design an algorithm that collects daily price quotes for some stock and returns the span of that stock's price for the current day.
#
# The span of the stock's price in one day is the maximum number of consecutive days (starting from that day and going backward) for which the stock price was less than or equal to the price of that day.
#
# For example, if the prices of the stock in the last four days is [7,2,1,2] and the price of the stock today is 2, then the span of today is 4 because starting from today, the price of the stock was less than or equal 2 for 4 consecutive days.
# Also, if the prices of the stock in the last four days is [7,34,1,2] and the price of the stock today is 8, then the span of today is 3 because starting from today, the price of the stock was less than or equal 8 for 3 consecutive days.
# Implement the StockSpanner class:
#
# StockSpanner() Initializes the object of the class.
# int next(int price) Returns the span of the stock's price given that today's price is price.
#
#
# Example 1:
#
# Input
# ["StockSpanner", "next", "next", "next", "next", "next", "next", "next"]
# [[], [100], [80], [60], [70], [60], [75], [85]]
# Output
# [null, 1, 1, 1, 2, 1, 4, 6]
#
# Explanation
# StockSpanner stockSpanner = new StockSpanner();
# stockSpanner.next(100); // return 1
# stockSpanner.next(80);  // return 1
# stockSpanner.next(60);  // return 1
# stockSpanner.next(70);  // return 2
# stockSpanner.next(60);  // return 1
# stockSpanner.next(75);  // return 4, because the last 4 prices (including today's price of 75) were less than or equal to today's price.
# stockSpanner.next(85);  // return 6
#
#
# Constraints:
#
# 1 <= price <= 105
# At most 104 calls will be made to next.

# %%
# this is better in understanding.

class StockSpanner:

    def __init__(self):
        self.stack: list[int] = []
        self.index: int = -1

    def next(self, price: int) -> int:
        # we are gonna maintain the decreasing stack. since we want to keep the prev max.
        while self.stack and self.stack[-1][0] < price:
            self.stack.pop()

        # increase the index, to track the index.
        self.index += 1

        print("before res")
        print(self.stack, self.index)

        # Get the res, before appending the new price. 
        # 
        if self.stack:
            res = (self.index - self.stack[-1][1])
        else:
            # when there is no element in the stack, means --> there is no bigger element thatn this.
            # [1,2,10] - for 10 the stack will be empty.
            # and the count should be 2 - (-1) = 3.
            res = (self.index - (-1))

        # Keep only the maximum value.
        self.stack.append((price, self.index))

        print(self.stack, self.index)

        # Now the result is, cur_ind - the previous max index.
        return res

# tc - Time (amortized per call) - O(1) - for most of hte call
# - O(n) in wost case, when it has to pop all the elements
# sc - O(n)


# Your StockSpanner object will be instantiated and called as such:
# obj = StockSpanner()
# param_1 = obj.next(price)

# %%
obj = StockSpanner()

# %%
print(obj.next(100))
print(obj.next(80))
print(obj.next(60))
print(obj.next(70))
print(obj.next(60))
print(obj.next(75))
print(obj.next(85))
print(obj.next(100))
# Out:
# before res
# [] 0
# [(100, 0)] 0
# 1
# before res
# [(100, 0)] 1
# [(100, 0), (80, 1)] 1
# 1
# before res
# [(100, 0), (80, 1)] 2
# [(100, 0), (80, 1), (60, 2)] 2
# 1
# before res
# [(100, 0), (80, 1)] 3
# [(100, 0), (80, 1), (70, 3)] 3
# 2
# before res
# [(100, 0), (80, 1), (70, 3)] 4
# [(100, 0), (80, 1), (70, 3), (60, 4)] 4
# 1
# before res
# [(100, 0), (80, 1)] 5
# [(100, 0), (80, 1), (75, 5)] 5
# 4
# before res
# [(100, 0)] 6
# [(100, 0), (85, 6)] 6
# 6
# before res
# [(100, 0)] 7
# [(100, 0), (100, 7)] 7
# 7

# %%
obj = StockSpanner()

print(obj.next(31))
print(obj.next(41))
print(obj.next(48))
print(obj.next(59))
print(obj.next(79))
# Out:
# before res
# [] 0
# [(31, 0)] 0
# 1
# before res
# [] 1
# [(41, 1)] 1
# 2
# before res
# [] 2
# [(48, 2)] 2
# 3
# before res
# [] 3
# [(59, 3)] 3
# 4
# before res
# [] 4
# [(79, 4)] 4
# 5

# %% [markdown]
# Sure! Let's walk through the **Stock Span Problem** for the input:
#
# ```
# [100, 80, 60, 70, 60, 75, 85]
# ```
#
# We'll maintain a **monotonic decreasing stack** storing `(price, index)` and calculate the span as:
#
# ```
# span[i] = i - prev_higher_price_index
# ```
#
# ---
#
# ### Initial State:
#
# ```markdown
# Stack: (empty)
# Index: -1
# ```
#
# ---
#
# ### Step-by-step:
#
# #### 🔹 Input: 100 at index 0
#
# * Stack is empty → span = 1
# * Push `(100, 0)`
#
# ```markdown
# | 100, 0 | <- Top
# ‾‾‾‾‾‾‾‾‾
# Span: 1
# ```
#
# ---
#
# #### 🔹 Input: 80 at index 1
#
# * 80 < 100 → span = 1
# * Push `(80, 1)`
#
# ```markdown
# | 80, 1 | <- Top
# |100, 0 |
# ‾‾‾‾‾‾‾‾‾
# Span: 1
# ```
#
# ---
#
# #### 🔹 Input: 60 at index 2
#
# * 60 < 80 → span = 1
# * Push `(60, 2)`
#
# ```markdown
# | 60, 2 | <- Top
# | 80, 1 |
# |100, 0 |
# ‾‾‾‾‾‾‾‾‾
# Span: 1
# ```
#
# ---
#
# #### 🔹 Input: 70 at index 3
#
# * 70 > 60 → pop
# * 70 < 80 → stop
# * Prev higher = index 1 → span = 3 - 1 = 2
# * Push `(70, 3)`
#
# ```markdown
# | 70, 3 | <- Top
# | 80, 1 |
# |100, 0 |
# ‾‾‾‾‾‾‾‾‾
# Span: 2
# ```
#
# ---
#
# #### 🔹 Input: 60 at index 4
#
# * 60 < 70 → span = 1
# * Push `(60, 4)`
#
# ```markdown
# | 60, 4 | <- Top
# | 70, 3 |
# | 80, 1 |
# |100, 0 |
# ‾‾‾‾‾‾‾‾‾
# Span: 1
# ```
#
# ---
#
# #### 🔹 Input: 75 at index 5
#
# * 75 > 60 → pop
# * 75 > 70 → pop
# * 75 < 80 → stop
# * Prev higher = index 1 → span = 5 - 1 = 4
# * Push `(75, 5)`
#
# ```markdown
# | 75, 5 | <- Top
# | 80, 1 |
# |100, 0 |
# ‾‾‾‾‾‾‾‾‾
# Span: 4
# ```
#
# ---
#
# #### 🔹 Input: 85 at index 6
#
# * 85 > 75 → pop
# * 85 < 80 → stop
# * Prev higher = index 1 → span = 6 - 1 = 5
# * Push `(85, 6)`
#
# ```markdown
# | 85, 6 | <- Top
# | 80, 1 |
# |100, 0 |
# ‾‾‾‾‾‾‾‾‾
# Span: 6
# ```
#
# ---
#
# ### ✅ Final Output Spans:
#
# ```
# [1, 1, 1, 2, 1, 4, 6]
# ```
#
# Let me know if you want a Python function to auto-visualize this!

# %% [markdown]
# # Another way of finding this.

# %%
class StockSpanner:

    def __init__(self):
        self.ss = []

    def next(self, price: int) -> int:
        curr_span = 1
        curr_price = price
        
        while self.ss and self.ss[-1][0] <= price:
            prev = self.ss.pop()
            curr_span += prev[1]

        self.ss.append([curr_price, curr_span])
        return curr_span

# Your StockSpanner object will be instantiated and called as such:
# obj = StockSpanner()
# param_1 = obj.next(price)

# %% [markdown]
# Here's a **minimal walkthrough** of the input:
# `[100, 80, 60, 70, 60, 75, 85]`
# We'll maintain a **monotonic decreasing stack** storing `[price, span]`.
#
# ---
#
# ### ➤ Call 1: `100`
#
# * Stack empty, span = 1
#   **Stack:**
#
# ```
# |100, 1|  <- Top
# ```
#
# Output: `1`
#
# ---
#
# ### ➤ Call 2: `80`
#
# * `80 < 100`, span = 1
#   **Stack:**
#
# ```
# | 80, 1|  <- Top
# |100, 1|
# ```
#
# Output: `1`
#
# ---
#
# ### ➤ Call 3: `60`
#
# * `60 < 80`, span = 1
#   **Stack:**
#
# ```
# | 60, 1|  <- Top
# | 80, 1|
# |100, 1|
# ```
#
# Output: `1`
#
# ---
#
# ### ➤ Call 4: `70`
#
# * Pop `60` → `span = 2`
# * `70 < 80` → stop
#   **Stack:**
#
# ```
# | 70, 2|  <- Top
# | 80, 1|
# |100, 1|
# ```
#
# Output: `2`
#
# ---
#
# ### ➤ Call 5: `60`
#
# * `60 < 70`, span = 1
#   **Stack:**
#
# ```
# | 60, 1|  <- Top
# | 70, 2|
# | 80, 1|
# |100, 1|
# ```
#
# Output: `1`
#
# ---
#
# ### ➤ Call 6: `75`
#
# * Pop `60` (1) → span = 2
# * Pop `70` (2) → span = 4
# * `75 < 80` → stop
#   **Stack:**
#
# ```
# | 75, 4|  <- Top
# | 80, 1|
# |100, 1|
# ```
#
# Output: `4`
#
# ---
#
# ### ➤ Call 7: `85`
#
# * Pop `75` (4) → span = 5
# * Pop `80` (1) → span = 6
# * `85 < 100` → stop
#   **Stack:**
#
# ```
# | 85, 6|  <- Top
# |100, 1|
# ```
#
# Output: `6`
#
# ---
#
# ### ✅ Final Outputs:
#
# ```
# [1, 1, 1, 2, 1, 4, 6]
# ```
#
# Let me know if you want the index info also shown, like `|price, span, index|`.
