# %% [markdown]
# Write a program to solve a Sudoku puzzle by filling the empty cells.
#
# A sudoku solution must satisfy all of the following rules:
#
# Each of the digits 1-9 must occur exactly once in each row.
# Each of the digits 1-9 must occur exactly once in each column.
# Each of the digits 1-9 must occur exactly once in each of the 9 3x3 sub-boxes of the grid.
# The '.' character indicates empty cells.
#
#
#
# Example 1:
#
#
# Input: board = [["5","3",".",".","7",".",".",".","."],["6",".",".","1","9","5",".",".","."],[".","9","8",".",".",".",".","6","."],["8",".",".",".","6",".",".",".","3"],["4",".",".","8",".","3",".",".","1"],["7",".",".",".","2",".",".",".","6"],[".","6",".",".",".",".","2","8","."],[".",".",".","4","1","9",".",".","5"],[".",".",".",".","8",".",".","7","9"]]
# Output: [["5","3","4","6","7","8","9","1","2"],["6","7","2","1","9","5","3","4","8"],["1","9","8","3","4","2","5","6","7"],["8","5","9","7","6","1","4","2","3"],["4","2","6","8","5","3","7","9","1"],["7","1","3","9","2","4","8","5","6"],["9","6","1","5","3","7","2","8","4"],["2","8","7","4","1","9","6","3","5"],["3","4","5","2","8","6","1","7","9"]]
# Explanation: The input board is shown above and the only valid solution is shown below:
#
#
#
#
# Constraints:
#
# board.length == 9
# board[i].length == 9
# board[i][j] is a digit or '.'.
# It is guaranteed that the input board has only one solution.

# %%
class Solution:
    def solveSudoku(self, board: list[list[str]]) -> None:
        def is_valid(row: int, col: int, digit: str) -> bool:
            # Check if the digit is not in the current row, column, or 3x3 box
            for i in range(9):
                if board[row][i] == digit: return False  # check row
                if board[i][col] == digit: return False  # check column
                
                # check 3x3 box
                box_row = 3 * (row // 3) + i // 3
                box_col = 3 * (col // 3) + i % 3
                if board[box_row][box_col] == digit: return False
            return True

        def backtrack() -> bool:
            for row in range(9):
                for col in range(9):
                    if board[row][col] == '.':
                        # Try digits from 1 to 9
                        for digit in '123456789':
                            if is_valid(row, col, digit):
                                board[row][col] = digit  # place digit

                                if backtrack():
                                    return True  # solved

                                board[row][col] = '.'  # backtrack
                        return False  # no valid digit found for this cell
            return True  # board completely filled

        backtrack()


# tc - O(9^(n)) - where n is the number of empty cells  
# Many invalid paths are pruned early due to the is_valid() check.

# sc - O(81) - recurssion depth is at max 81 cells = O(1)

# %% [markdown]
# for pepople who might be confused at first sight about the line:
# if board[3*(row//3) + i//3][3*(col//3) + i%3] == ch: return False
# :
# i=1 i//3=0 i%3=1
# i=2 i//3=0 i%3=2
# i=3 i//3=1 i%3=0
# i=4 i//3=1 i%3=1
# i=5 i//3=1 i%3=2
# i=6 i//3=2 i%3=0
# i=7 i//3=2 i%3=1
# i=8 i//3=2 i%3=2
# i=9 i//3=3 i%3=0
# adding them to current row and column do represent the 3x3 subbox.
#
# new expression learnt (for me)
